# %% [markdown]
# # Assignments: Cleaning Data

# %% [markdown]
# ## 1. Data in Python Request

# %% [markdown]
# * Read in data from the Excel spreadsheet (Alarm Survey Data.xlsx) and put into a Pandas DataFrame
# * Check the data type of each column
# * Convert object columns into numeric or datetime columns, as needed

# %%
import pandas as pd

# %%
pd.read_excel('../Data/Alarm Survey Data.xlsx')
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# 1                     3      3 stars
# 2                     1      1 stars
# 3                     1      4 stars
# 4                     4      3 stars
# ...                 ...          ...
# 6428                  0      5 stars
# 6429                  0      4 stars
# 6430                  0      3 stars
# 6431                  0      3 stars
# 6432                  0      1 stars
#
# [6433 rows x 7 columns]

# %%
df = pd.read_excel('../Data/Alarm Survey Data.xlsx')
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# 1                     3      3 stars
# 2                     1      1 stars
# 3                     1      4 stars
# 4                     4      3 stars
# ...                 ...          ...
# 6428                  0      5 stars
# 6429                  0      4 stars
# 6430                  0      3 stars
# 6431                  0      3 stars
# 6432                  0      1 stars
#
# [6433 rows x 7 columns]

# %%
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6082.000000
# mean   3216.302192    29.069175            1.395616       4.232654
# std    1856.007409     7.472048            1.432192       0.842448
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes
# count        6433.000000
# mean            1.145811
# std             1.599481
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             2.000000
# max            19.000000

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating           object
# dtype: object

# %%
df.alarm_rating.str.replace('stars', '')
# Out:
# 0       5
# 1       3
# 2       1
# 3       4
# 4       3
#         ..
# 6428    5
# 6429    4
# 6430    3
# 6431    3
# 6432    1
# Name: alarm_rating, Length: 6433, dtype: object

# %%
pd.to_numeric(df.alarm_rating.str.replace('stars', ''))
# Out:
# 0       5
# 1       3
# 2       1
# 3       4
# 4       3
#        ..
# 6428    5
# 6429    4
# 6430    3
# 6431    3
# 6432    1
# Name: alarm_rating, Length: 6433, dtype: int64

# %%
df.alarm_rating = pd.to_numeric(df.alarm_rating.str.replace('stars', ''))

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %%
df.head(10)
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
# 5          6   25                 0.0  lightly active            4.0
# 6          7   41                 5.5  lightly active            1.0
# 7          8   36                 5.5  lightly active            1.0
# 8          9   27                 0.0  lightly active            3.0
# 9         10   29                 0.0  light_activity            3.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3
# 5                  4             3
# 6                  1             2
# 7                  1             2
# 8                  4             2
# 9                  1             4

# %% [markdown]
# ## 2. Missing Data Check

# %% [markdown]
# * Find any missing data
# * Deal with the missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 351.9+ KB

# %%
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                 2.0  light_activity            NaN
# 18           19   38                 2.0  lightly active            NaN
# 23           24   24                 2.0     very active            NaN
# 26           27   25                 2.0  lightly active            NaN
# 28           29   29                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                 2.0     very active            NaN
# 6319       6320   44                 2.0  lightly active            NaN
# 6375       6309   32                 3.0           light            NaN
# 6377       6311   30                 2.0     very active            NaN
# 6386       6320   44                 2.0  lightly active            NaN
#
#       number_of_snoozes  alarm_rating
# 10                    3             4
# 18                    1             5
# 23                    1             5
# 26                    1             2
# 28                    1             2
# ...                 ...           ...
# 6310                  0             3
# 6319                  0             3
# 6375                  0             3
# 6377                  0             3
# 6386                  0             3
#
# [351 rows x 7 columns]

# %%
df.sleep_quality.value_counts()
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# 1.0     103
# Name: count, dtype: int64

# %%
df.sleep_quality.value_counts(dropna=False) # to see missing values
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: count, dtype: int64

# %%
df.sleep_quality.fillna(2) # fill missing values as 2
# Out:
# 0       3.0
# 1       3.0
# 2       4.0
# 3       4.0
# 4       1.0
#        ...
# 6428    5.0
# 6429    4.0
# 6430    5.0
# 6431    5.0
# 6432    4.0
# Name: sleep_quality, Length: 6433, dtype: float64

# %%
df.sleep_quality.fillna(2).value_counts(dropna=False) # value_counts is to see unique values in column
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: count, dtype: int64

# %%
df.info() # missing vlues are still hasn't updated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 351.9+ KB

# %%
df.sleep_quality.fillna(2, inplace=True) # to update values to data frame

# %%
df.info() # to check if missing values are all handled
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6433 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 351.9+ KB

# %%
# to dbl check in different way -> NaN values are updated
df.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Inconsistent Text & Typos Check

# %% [markdown]
# * Find any inconsistent text and typos
# * Deal with the inconsistent text and typos

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df.describe() # number of children is needed to look into as it's decimal
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6433.000000
# mean   3216.302192    29.069175            1.395616       4.110835
# std    1856.007409     7.472048            1.432192       0.963415
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000   6433.000000
# mean            1.145811      2.955075
# std             1.599481      1.101363
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max            19.000000      5.000000

# %%
df.number_of_children.value_counts() # 5.5 seems the way to represent more than 5 children
# Out:
# number_of_children
# 0.0    2440
# 2.0    1498
# 1.0    1172
# 3.0     788
# 4.0     331
# 5.5     204
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df.activity_level.value_counts() # categories are similar
# Out:
# activity_level
# active            2450
# lightly active    2289
# light_activity     691
# very active        669
# light              334
# Name: count, dtype: int64

# %%
# change light_activity and light to Lightly active
import numpy as np

# %%
np.where(df.activity_level.isin(['light_activity', 'light']), 'lightly active', df.activity_level)
# Out:
# array(['active', 'lightly active', 'lightly active', ...,
#        'lightly active', 'active', 'lightly active'], dtype=object)

# %%
# set the new values as dataframe 
df.activity_level = np.where(df.activity_level.isin(['light_activity', 'light']), 'lightly active', df.activity_level)

# %%
df.activity_level.value_counts() # check new value counts
# Out:
# activity_level
# lightly active    3314
# active            2450
# very active        669
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Duplicate Data Check

# %% [markdown]
# * Find any duplicate data
# * Deal with the duplicate data

# %%
df[df.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6366       6300   31                 2.0          active            5.0
# 6367       6301   27                 2.0  lightly active            4.0
# 6368       6302   41                 3.0  lightly active            5.0
# 6369       6303   25                 0.0  lightly active            5.0
# 6370       6304   25                 1.0  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 6366                  0             3
# 6367                  0             2
# 6368                  0             2
# 6369                  0             5
# 6370                  0             2
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [67 rows x 7 columns]

# %%
df.shape
# Out:
# (6433, 7)

# %%
df[~df.duplicated()] # using '~' for storing non-duplicated data
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6366 rows x 7 columns]

# %%
# save data 
df = df[~df.duplicated()]

# %% [markdown]
# ## 5. Outliers Check

# %% [markdown]
# * Find any outliers
# * Deal with the outliers

# %%
df.hist() # number of snooze is skewed and needs to be checked
# Out:
# array([[<Axes: title={'center': 'survey_id'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'number_of_children'}>,
#         <Axes: title={'center': 'sleep_quality'}>],
#        [<Axes: title={'center': 'number_of_snoozes'}>,
#         <Axes: title={'center': 'alarm_rating'}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.histplot(df.number_of_snoozes)
# Out:
# <Axes: xlabel='number_of_snoozes', ylabel='Count'>

# %%
sns.boxplot(x = df.number_of_snoozes)
# Out:
# <Axes: xlabel='number_of_snoozes'>

# %%
df.number_of_snoozes.value_counts()
# Out:
# number_of_snoozes
# 0     3300
# 1     1229
# 2      693
# 4      427
# 5      345
# 3      309
# 6       59
# 8        2
# 19       1
# 7        1
# Name: count, dtype: int64

# %%
# filter out extreme outlier
df[df.number_of_snoozes >= 19]
# Out:
#      survey_id  age  number_of_children  activity_level  sleep_quality  \
# 749        750   19                 1.0  lightly active            5.0
#
#      number_of_snoozes  alarm_rating
# 749                 19             3

# %%
# reverse the outlier to keep the data
df[df.number_of_snoozes < 19]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6365 rows x 7 columns]

# %%
df = df[df.number_of_snoozes < 19]

# %% [markdown]
# ## 6. Data Issues Check

# %% [markdown]
# * Quickly explore the updated DataFrame. How do things look now after handling the data issues compared to the original DataFrame?

# %%
# missing data
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# inconsistencies
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0  lightly active            3.0
# 2          3   18                 0.0  lightly active            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  lightly active            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df.activity_level.value_counts()
# Out:
# activity_level
# lightly active    3287
# active            2422
# very active        656
# Name: count, dtype: int64

# %%
# duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# outliers
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6365.000000  6365.000000         6365.000000    6365.000000
# mean   3183.882325    29.076826            1.396936       4.107620
# std    1837.741432     7.476376            1.433575       0.963612
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1593.000000    23.000000            0.000000       4.000000
# 50%    3184.000000    28.000000            1.000000       4.000000
# 75%    4775.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6365.000000   6365.000000
# mean            1.155067      2.955224
# std             1.587979      1.100414
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max             8.000000      5.000000

# %% [markdown]
# ## 7. Create Columns From Numeric Data

# %% [markdown]
# * Read data into Python
# * Check the data type of each column
# * Create a numeric column using arithmetic
# * Create a numeric column using conditional logic

# %%
import pandas as pd

# %%
pens = pd.read_excel('../Data/Pen Sales Data.xlsx')

pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...

# %%
pens.dtypes
# Out:
# Customer                  int64
# Item                     object
# Pen Cost                float64
# Shipping Cost           float64
# Purchase Date    datetime64[ns]
# Delivery Date    datetime64[ns]
# Review                   object
# dtype: object

# %%
# Create a “Total Spend” column that includes both the pen cost and shipping cost for each sale
pens['Pen Cost']+ pens['Shipping Cost']

pens['Total Spend'] = pens['Pen Cost']+ pens['Shipping Cost']
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend
# 0         8.98
# 1        12.99
# 2        11.94
# 3         8.98
# 4        14.98

# %%
# Create a “Free Shipping” column that says yes if the sale included free shipping, and no otherwise
import numpy as np

# %%
np.where(pens['Shipping Cost'] == 0, 'yes', 'no')
# Out:
# array(['no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no',
#        'no', 'yes', 'no', 'no'], dtype='<U3')

# %%
pens['Free Shipping'] = np.where(pens['Shipping Cost'] == 0, 'yes', 'no')
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping
# 0         8.98            no
# 1        12.99           yes
# 2        11.94            no
# 3         8.98            no
# 4        14.98            no

# %% [markdown]
# ## 8. Create Columns From DateTime Data

# %% [markdown]
# * Calculate the difference between two datetime columns and save it as a new column
# * Take the average of a column

# %%
# Calculate the number of days between the purchase and delivery date for each sale
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping
# 0         8.98            no
# 1        12.99           yes
# 2        11.94            no
# 3         8.98            no
# 4        14.98            no

# %%
pens['Delivery Date'] - pens['Purchase Date']
# Out:
# 0    2 days
# 1    3 days
# 2    1 days
# 3    3 days
# 4    2 days
# 5    3 days
# 6    2 days
# 7    6 days
# 8    5 days
# 9    1 days
# 10   3 days
# 11   6 days
# 12   2 days
# 13   6 days
# 14   2 days
# 15   2 days
# 16   2 days
# 17   1 days
# 18   5 days
# 19   5 days
# 20   3 days
# 21   3 days
# 22   4 days
# 23   4 days
# 24   5 days
# dtype: timedelta64[ns]

# %%
# Save it as a new column called “Delivery Time”
pens['Delivery Time'] = pens['Delivery Date'] - pens['Purchase Date']

# %%
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time
# 0         8.98            no        2 days
# 1        12.99           yes        3 days
# 2        11.94            no        1 days
# 3         8.98            no        3 days
# 4        14.98            no        2 days

# %%
# to see the average of delivery time
pens['Delivery Time'].mean()
# Out:
# Timedelta('3 days 05:45:36')

# %% [markdown]
# ## 9. Create Columns From Text Data

# %% [markdown]
# * Split one column into multiple columns
# * Create a Boolean column (True / False) to show whether a text field contains particular words

# %%
# Split the reviews on the “|” character to create two new columns: “User Name” and “Review Text”
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time
# 0         8.98            no        2 days
# 1        12.99           yes        3 days
# 2        11.94            no        1 days
# 3         8.98            no        3 days
# 4        14.98            no        2 days

# %%
pens.Review.str.split('|')
reviews = pens.Review.str.split('|')

reviews.head()
# Out:
# 0    [DoodleWithMe, I love the way this pen writes,...
# 1    [ScribbleMaster, The classic Sharpie marker ha...
# 2    [PenPalForever, The retractable ballpoint pen ...
# 3    [TheWriteWay, This gel pen has a comfortable g...
# 4    [PenAndPaperPerson, The rollerball pen has a s...
# Name: Review, dtype: object

# %%
# put them into new data frame
pd.DataFrame(reviews.to_list())
# Out:
#                         0                                                  1
# 0            DoodleWithMe  I love the way this pen writes, but unfortunat...
# 1          ScribbleMaster  The classic Sharpie marker has a bold, permane...
# 2           PenPalForever  The retractable ballpoint pen has a durable, m...
# 3             TheWriteWay  This gel pen has a comfortable grip and writes...
# 4       PenAndPaperPerson  The rollerball pen has a smooth, fluid feel an...
# 5       SmoothOperatorPen  This gel pen writes smoothly with a bold, vibr...
# 6       InkStainedFingers  This pen is prone to leaking and can create a ...
# 7           BoldInkWriter  Unfortunately, this pen has a tendency to spil...
# 8           PenmanshipPro  The gel pen has a comfortable grip and writes ...
# 9              GelPenGuru  This retractable gel pen has a fine point that...
# 10           FinePointFan  Be careful with this pen, as it has been known...
# 11      SignatureStylePen  The retractable ballpoint pen is convenient an...
# 12    BoldAndBeautifulPen
# 13        RollerballRider  The ink in this pen has a tendency to leak out...
# 14        BallpointBandit  This ballpoint pen has a sleek design and writ...
# 15      TwistAndWriteUser  The ink in this pen can sometimes leak out of ...
# 16        ThePenWhisperer
# 17        InkFlowFollower  I was disappointed to find that this pen leake...
# 18       ThePenAndInkLady  This ballpoint pen has a comfortable grip and ...
# 19  WritingInstrumentsFan  This pen is great for writing, but it's not ve...
# 20        PenPrecisionPro  The retractable Sharpie marker is convenient a...
# 21           InkCollector  The ballpoint pen is lightweight and comfortab...
# 22  PenToPaperPersonality
# 23    SmoothWritingScribe  This fine point Sharpie marker has a precise t...
# 24    ThePenmanshipPundit  This pen writes smoothly and delivers a crisp ...

# %%
# give the columns name
pens[['User Name', 'Review Text']] = pd.DataFrame(reviews.to_list())

# %%
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time          User Name  \
# 0         8.98            no        2 days       DoodleWithMe
# 1        12.99           yes        3 days     ScribbleMaster
# 2        11.94            no        1 days      PenPalForever
# 3         8.98            no        3 days        TheWriteWay
# 4        14.98            no        2 days  PenAndPaperPerson
#
#                                          Review Text
# 0  I love the way this pen writes, but unfortunat...
# 1  The classic Sharpie marker has a bold, permane...
# 2  The retractable ballpoint pen has a durable, m...
# 3  This gel pen has a comfortable grip and writes...
# 4  The rollerball pen has a smooth, fluid feel an...

# %%
# Create a “Leak or Spill” column that flags the reviews that mention either “leak” or “spill”
pens.Review.str.contains('Leak|Spill', regex=True)
pens['Leak or Spill'] = pens.Review.str.contains('leak|spill', regex=True)

# %%
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time          User Name  \
# 0         8.98            no        2 days       DoodleWithMe
# 1        12.99           yes        3 days     ScribbleMaster
# 2        11.94            no        1 days      PenPalForever
# 3         8.98            no        3 days        TheWriteWay
# 4        14.98            no        2 days  PenAndPaperPerson
#
#                                          Review Text  Leak or Spill
# 0  I love the way this pen writes, but unfortunat...           True
# 1  The classic Sharpie marker has a bold, permane...          False
# 2  The retractable ballpoint pen has a durable, m...          False
# 3  This gel pen has a comfortable grip and writes...          False
# 4  The rollerball pen has a smooth, fluid feel an...          False
